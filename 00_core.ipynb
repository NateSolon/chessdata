# %%
# default_exp core

# %% [markdown]
# # module name here
#
# > API details.

# %%
#hide
from nbdev.showdoc import *

# %%
#export
def hello(name):
    return f"Hello {name}!"

# %%
hello("Nate")
# Out:
# 'Hello Nate!'
